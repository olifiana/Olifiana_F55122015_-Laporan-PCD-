# %% [markdown]
# <a href="https://colab.research.google.com/github/olifiana/Olifiana_F55122015_-Laporan-PCD-/blob/main/Modul2_Olifiana_F55122015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/Mommogram.tiff")

# %%
img_1 = 225 - img

# %%
plt.subplot(2, 2, 1)
plt.imshow(img)
plt.title('Original Image')
plt.subplot(2, 2, 2)
plt.imshow(img_1)
plt.title('Image Negative')
# Out:
# Text(0.5, 1.0, 'Image Negative')

# %%
cv2.waitKey(0)
cv2.destroyAllWindows ()
